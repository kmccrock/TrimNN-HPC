# %% [markdown]
# Eli Lilly - CosMx - Kidney
#
# Data Prep

# %%
import numpy as np
import pandas as pd

# %%
# Import csv to split
S1 = pd.read_csv("data/S1.csv")
S2 = pd.read_csv("data/S2.csv")
S3 = pd.read_csv("data/S3.csv")

# %%
S1
# Out:
#           X     Y                           cell_type
# 0       126  3623  epithelial.cell.of.proximal.tubule
# 1       296  3573                 papillary.tips.cell
# 2       585  3627                                   a
# 3       840  3625                                   a
# 4      1463  3622                                   a
# ...     ...   ...                                 ...
# 68559  4386    69                                   a
# 68560  4466    67                                   a
# 68561  2539    75                                   a
# 68562   970    59                    endothelial.cell
# 68563   670    46                                   d
#
# [68564 rows x 3 columns]

# %%
#S1 

# Calculate the median values for X and Y
median_X = S1["X"].median()
median_Y = S1["Y"].median()

# Define conditions for each quadrant
Q4 = S1[(S1["X"] >= median_X) & (S1["Y"] >= median_Y)]
Q3 = S1[(S1["X"] < median_X) & (S1["Y"] >= median_Y)]
Q1 = S1[(S1["X"] < median_X) & (S1["Y"] < median_Y)]
Q2 = S1[(S1["X"] >= median_X) & (S1["Y"] < median_Y)]

# Save each quadrant into a separate CSV file
Q1.to_csv("data/S1_1.csv", index=False)
Q2.to_csv("data/S1_2.csv", index=False)
Q3.to_csv("data/S1_3.csv", index=False)
Q4.to_csv("data/S1_4.csv", index=False)

# %%
#S2 

# Calculate the median values for X and Y
median_X = S2["X"].median()
median_Y = S2["Y"].median()

# Define conditions for each quadrant
Q4 = S2[(S2["X"] >= median_X) & (S2["Y"] >= median_Y)]
Q3 = S2[(S2["X"] < median_X) & (S2["Y"] >= median_Y)]
Q1 = S2[(S2["X"] < median_X) & (S2["Y"] < median_Y)]
Q2 = S2[(S2["X"] >= median_X) & (S2["Y"] < median_Y)]

# Save each quadrant into a separate CSV file
Q1.to_csv("data/S2_1.csv", index=False)
Q2.to_csv("data/S2_2.csv", index=False)
Q3.to_csv("data/S2_3.csv", index=False)
Q4.to_csv("data/S2_4.csv", index=False)

# %%
#S3 

# Calculate the median values for X and Y
median_X = S3["X"].median()
median_Y = S3["Y"].median()

# Define conditions for each quadrant
Q4 = S3[(S3["X"] >= median_X) & (S3["Y"] >= median_Y)]
Q3 = S3[(S3["X"] < median_X) & (S3["Y"] >= median_Y)]
Q1 = S3[(S3["X"] < median_X) & (S3["Y"] < median_Y)]
Q2 = S3[(S3["X"] >= median_X) & (S3["Y"] < median_Y)]

# Save each quadrant into a separate CSV file
Q1.to_csv("data/S3_1.csv", index=False)
Q2.to_csv("data/S3_2.csv", index=False)
Q3.to_csv("data/S3_3.csv", index=False)
Q4.to_csv("data/S3_4.csv", index=False)
